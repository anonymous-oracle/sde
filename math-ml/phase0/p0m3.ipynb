# %% [markdown]
# ***
#
# ### **Module 03, Node 1: Fractions & Typological Syntax**
#
# **Textbook Reference:** Selina Concise Mathematics (Class 6) -> Chapter 14: Fractions -> Pages 128-140 (Standard Edition Span).
#
# **1. Supermarket Intuition**
# We defined Rational Numbers ($\mathbb{Q}$) as ratios of integers ($\frac{p}{q}$). However, before we abstracted to negative ratios, elementary mathematics established "Fractions" strictly as fragments of a positive whole. In data structures, when you slice an array or calculate a normalized probability between 0 and 1, you are performing fractional arithmetic. We must formally define the structural types of these fragments so we can write algorithms to convert between them without data loss.
#
# **2. Bounded Rigorous Derivation**
# At our current bound, a fraction is defined as $\frac{a}{b}$, where $a, b \in \mathbb{W}$ (Whole numbers) and $b \neq 0$.
# * **$a$ (Numerator):** The count of the fragments we possess.
# * **$b$ (Denominator):** The total number of equal fragments that constitute exactly one whole unit.
#
# **Typological Classification:**
# 1.  **Proper Fraction:** The absolute value of the numerator is strictly less than the denominator ($a < b$). The total value is strictly $< 1$. Example: $\frac{3}{5}$.
# 2.  **Improper Fraction:** The numerator is greater than or equal to the denominator ($a \ge b$). The total value is $\ge 1$. Example: $\frac{7}{4}$.
# 3.  **Mixed Fraction (Mixed Number):** A composite syntax consisting of an integer and a proper fraction. Example: $1 \frac{3}{4}$, which mathematically means $1 + \frac{3}{4}$.
#
# **Algorithmic Conversion:**
# * **Mixed to Improper:** For $Q \frac{R}{D}$ (where $Q$ is quotient/integer, $R$ is remainder/numerator, $D$ is divisor/denominator), the improper numerator is $(Q \times D) + R$. The denominator $D$ remains unchanged.
#     * $$2 \frac{3}{5} = \frac{(2 \times 5) + 3}{5} = \frac{13}{5}$$
# * **Equivalent Fractions:** By the Identity Property of Multiplication (multiplying by $1$, or $\frac{n}{n}$), if we multiply or divide both $a$ and $b$ by the same non-zero scalar, the ratio's magnitude remains identical. $\frac{a}{b} = \frac{a \times n}{b \times n}$.
#
# **3. Practice Problems (Class 6 Level)**
# *Verified via Override Rule v14.1: Solutions map strictly to whole number arithmetic and rational definitions.*
#
# * **Problem 1 (Basic):** Classify the following fractions as Proper, Improper, or Mixed: $\frac{18}{5}$, $\frac{4}{9}$, $7 \frac{1}{2}$, $\frac{12}{12}$.
# * **Problem 2 (Basic):** Convert the mixed fraction $8 \frac{4}{7}$ into an improper fraction.
# * **Problem 3 (Medium):** Find an equivalent fraction for $\frac{5}{12}$ that has a denominator of $144$.
# * **Problem 4 (Medium):** Reduce the fraction $\frac{108}{256}$ to its lowest (standard) form.
# * **Problem 5 (Difficult):** Arrange the following fractions in ascending order by finding a common denominator: $\frac{2}{3}$, $\frac{5}{6}$, $\frac{7}{9}$, $\frac{1}{2}$.
# * **Problem 6 (Extension):** If $\frac{x}{15} = \frac{16}{60}$, solve for $x$ using the equivalent fraction property, without using cross-multiplication (which is an algebraic equation technique we have not yet formalized for this specific context).
#
# ***

# %% [markdown]
# ***
#
# ### **Module 03, Node 2: Fraction Operations (Addition, Subtraction, Multiplication, Division)**
#
# **Textbook Reference:** Selina Concise Mathematics (Class 6 & Class 7) -> Chapter 14 (Class 6) / Fractions (Class 7) -> Operations on Fractions.
#
# **1. Supermarket Intuition**
# When dealing with fractions, you are dealing with pieces of a defined whole. You cannot simply add a "third" of a pizza to a "fourth" of a pizza and say you have "two sevenths." That is a catastrophic failure of unit matching. In data engineering, trying to merge two datasets with different structural normalizations without aligning them first will corrupt your entire pipeline.
# Addition and Subtraction require a *common base unit* (a common denominator). Multiplication and Division, however, are scaling operations—you are taking a fragment *of* a fragment, which scales the numerators and denominators independently.
#
# **2. Bounded Rigorous Derivation**
# Let $\frac{a}{b}$ and $\frac{c}{d}$ be fractions where $b \neq 0$ and $d \neq 0$.
#
# * **Addition & Subtraction (The LCM Mandate):**
#     To compute $\frac{a}{b} \pm \frac{c}{d}$, we must first make the denominators identical. We find the Least Common Multiple (LCM) of $b$ and $d$. Let this LCM be $L$.
#     We convert both to equivalent fractions: $\frac{a \times n_1}{L} \pm \frac{c \times n_2}{L}$.
#     Once the denominators are identical, the operation only applies to the numerator:
#     $$\frac{x}{L} \pm \frac{y}{L} = \frac{x \pm y}{L}$$
#
# * **Multiplication (Scaling):**
#     Multiplication is a direct mapping of numerator to numerator and denominator to denominator.
#     $$\frac{a}{b} \times \frac{c}{d} = \frac{a \times c}{b \times d}$$
#
# * **Division (The Reciprocal):**
#     Division by a rational number is strictly defined as multiplication by its reciprocal.
#     $$\frac{a}{b} \div \frac{c}{d} = \frac{a}{b} \times \frac{d}{c}$$
#     *(Note: All mixed fractions must be converted to improper fractions before applying these operational algorithms.)*
#
# **3. Practice Problems (Class 6 & 7 Level)**
# *Verified via Override Rule v14.1: Solutions map strictly to the LCM mandate, scaling properties, and standard fraction syntax.*
#
# * **Problem 1 (Basic):** Evaluate and reduce to lowest terms: $\frac{3}{14} + \frac{5}{14}$.
# * **Problem 2 (Basic):** Evaluate: $\frac{7}{8} \times \frac{16}{21}$.
# * **Problem 3 (Medium):** Calculate: $\frac{5}{6} - \frac{3}{8}$.
# * **Problem 4 (Medium):** Evaluate the division of two mixed numbers: $3 \frac{1}{3} \div 1 \frac{4}{5}$.
# * **Problem 5 (Difficult):** Simplify using the correct order of operations (BODMAS applied to fractions): $\left( \frac{1}{2} + \frac{1}{4} \right) \times \frac{8}{9}$.
# * **Problem 6 (Extension):** Using the property that any fraction $\frac{X}{Y}$ is equivalent to $\frac{X \times n}{Y \times n}$ (Identity Property), algebraically prove that $\frac{a/b}{c/d} = \frac{a}{b} \times \frac{d}{c}$ by choosing a specific scalar $n$ to multiply both the top and bottom of the complex fraction.
#
# ***

# %% [markdown]
# ***
#
# ### **Module 03, Node 3: Decimal Fractions**
#
# **Textbook Reference:** Selina Concise Mathematics (Class 6 & Class 7) -> Decimal Fractions -> Pages 141-155 (Standard Edition Span).
#
# **1. Supermarket Intuition**
# Fractions are mathematically pure, but computationally expensive. If a computer has to constantly calculate LCMs to add probabilities together, the overhead is massive. To solve this, we force all fractions into a standardized denominator: powers of $10$. This allows us to drop the denominator entirely and simply use positional syntax—the decimal point. This is the absolute foundation of "floating-point arithmetic" used in every modern programming language to handle continuous data.
#
# **2. Bounded Rigorous Derivation**
# A decimal fraction is simply a fraction where the denominator is $10^k$ (where $k \in \mathbb{N}$).
# We utilize the negative indices we proved in Module 01 ($10^{-n} = \frac{1}{10^n}$).
#
# * **Positional Extension:**
#     $$0.d_1 d_2 d_3 = (d_1 \times 10^{-1}) + (d_2 \times 10^{-2}) + (d_3 \times 10^{-3})$$
#     $$0.d_1 d_2 d_3 = \frac{d_1}{10} + \frac{d_2}{100} + \frac{d_3}{1000}$$
#
# * **Addition & Subtraction (The Alignment Mandate):**
#     Because each position represents a strictly different denominator, you can only add tenths to tenths, and hundredths to hundredths. You must geometrically align the decimal points before executing the operation.
#
# * **Multiplication (Index Addition):**
#     When multiplying $0.A \times 0.B$:
#     If $A$ has $m$ decimal places (denominator $10^m$) and $B$ has $n$ decimal places (denominator $10^n$), the product $A \times B$ will have $m + n$ decimal places (denominator $10^{m+n}$, by the product law of exponents).
#
# * **Division (Index Subtraction):**
#     To divide by a decimal, we multiply both the dividend and divisor by $10^k$ (where $k$ is the number of decimal places in the divisor) to convert the divisor into a whole number, preserving the ratio via the Equivalent Fraction property.
#
# **3. Practice Problems (Class 6 & 7 Level)**
# *Verified via Override Rule v14.1: Solutions map strictly to the defined base-10 positional logic and equivalent fraction scalars.*
#
# * **Problem 1 (Basic):** Convert the fraction $\frac{17}{25}$ into a decimal by first converting it to an equivalent fraction with a denominator of $100$.
# * **Problem 2 (Basic):** Evaluate: $14.05 + 3.9 - 0.125$.
# * **Problem 3 (Medium):** Evaluate the product: $0.004 \times 1.2$.
# * **Problem 4 (Medium):** Evaluate the quotient: $0.0144 \div 0.12$.
# * **Problem 5 (Difficult):** Express the decimal $0.035$ as a fraction in its lowest standard form.
# * **Problem 6 (Extension):** Let $x = 0.5$ and $y = 0.05$. Without using a calculator, prove algebraically that $\frac{x}{y} = 10$ by converting both decimals into their strict fractional definitions ($\frac{a}{10^k}$) and executing rational division.
#
# ***

# %% [markdown]
# ***
#
# ### **Module 03, Node 4: The Unitary Method**
#
# **Textbook Reference:** Selina Concise Mathematics (Class 6) -> Chapter 13: Unitary Method & Class 7 -> Unitary Method.
#
# **1. Supermarket Intuition**
# If you know the cost of 5 identical apples, how do you mathematically derive the cost of 7? You cannot scale directly from 5 to 7 using a neat integer. You must first drop down to the "unit" scale—finding the cost of exactly *one* apple—and then multiply up to your target.
# In your eventual machine learning career, this is the conceptual grandfather of "data normalization". Before a neural network can compare a feature measured in thousands (like salary) against a feature measured in decimals (like click-through rate), it must compress both down to a unit scale of 1 before assigning weights.
#
# **2. Bounded Rigorous Derivation**
# Let $V$ be the total value or quantity associated with $a$ number of items.
# Let $C(n)$ represent the value of $n$ items. We are given $C(a) = V$.
#
# * **Step 1 (The Unitary Reduction):** Find the value of a single unit.
#   $$C(1) = \frac{V}{a}$$
# * **Step 2 (The Target Scaling):** Multiply the unit value by the desired target quantity, $b$.
#   $$C(b) = b \times C(1) = b \times \left(\frac{V}{a}\right)$$
#
# *(Note: Under our strict Bounded Rigor protocol, we are only dealing with "Direct Variation" here, where an increase in quantity strictly means an increase in value. Inverse variation, such as "more workers means less time," is formally locked until Class 8, Module 06.)*
#
# **3. Practice Problems (Class 6 & 7 Level)**
# *Verified via Override Rule v14.1: Solutions map strictly to the two-step direct unitary algorithm and previously unlocked fractional/decimal arithmetic.*
#
# * **Problem 1 (Basic):** If $15$ pens cost $120$ rupees, what is the exact cost of $8$ pens?
# * **Problem 2 (Basic):** A machine produces $450$ units of a product in $5$ hours. How many units will it produce in $12$ hours assuming a constant rate?
# * **Problem 3 (Medium):** A car travels $228$ km on $12$ liters of petrol. How far will it travel on $15$ liters?
# * **Problem 4 (Medium):** If the annual (12-month) rent of a server rack is $36,000$ rupees, what is the rent for exactly $5$ months?
# * **Problem 5 (Difficult):** The cost of $3 \frac{1}{2}$ kg of a chemical compound is $154$ rupees. Find the exact cost of $5 \frac{1}{4}$ kg of the same compound. (Combine your fractional division skills with the unitary method).
# * **Problem 6 (Extension):** A data entry operator is paid $1,050$ rupees for $6$ days of work. If his total earnings for a specific month were $4,375$ rupees, for how many days did he work? (Apply the unitary method in reverse: find the days per unit of currency, or unit cost per day).
#
# ***

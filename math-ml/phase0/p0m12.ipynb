# %% [markdown]
# ***
#
# ### **Module 12, Node 1: Quadratic Equations (Factorisation & Zero Product Rule)**
#
# **Textbook Reference Block (Exhaustive Parallel Citation Protocol v14.2):**
# * **Selina Concise Mathematics:** Class 10, Chapter 5: Quadratic Equations -> Page Range: Standard Edition Span.
# * **M.L. Aggarwal Understanding ICSE:** Class 10, Chapter 5: Quadratic Equations -> Page Range: Standard Edition Span.
# * **S. Chand's ICSE Mathematics:** Class 10, Quadratic Equations -> Page Range: Standard Edition Span.
# * **Frank Modern Certificate Mathematics:** Class 10, Quadratic Equations -> Page Range: Standard Edition Span.
# * **Together With ICSE Mathematics:** Class 10, Quadratic Equations -> Page Range: Standard Edition Span.
# * **R.S. Aggarwal Foundation Mathematics:** Class 10, Quadratic Equations -> Page Range: Standard Edition Span.
#
# **1. Supermarket Intuition**
# Linear equations form straight lines; they map constant rates of change. But the universe is rarely constant. If you throw a ball into the air, gravity decelerates it, stops it, and pulls it back down. The path is a parabola—a curve. In machine learning, when you train a neural network, you map out an "error curve" (a Cost Function). The algorithm's goal is to find the absolute lowest point (the valley) of that curve to minimize error. This curved architecture is defined by an equation where the highest power is $2$: a **Quadratic Equation**.
#
# **2. Bounded Rigorous Derivation**
# * **The Standard Form:** A quadratic equation in one variable is strictly defined as:
#   $$ax^2 + bx + c = 0$$
#   *(where $a, b,$ and $c$ are real numbers, and strictly $a \neq 0$).*
#
# * **The Roots of the Equation:**
#   In a linear equation ($ax + b = 0$), there is only one solution for $x$. Because a quadratic curve intersects the baseline twice, it yields **two solutions** (called *roots*).
#
# * **The Zero Product Rule (The Solving Algorithm):**
#   How do we solve for $x$ when we have both an $x^2$ term and an $x$ term? We cannot isolate it linearly. We must use the factorisation logic we unlocked in Module 10.
#   1. We manipulate the equation so the Right Hand Side (RHS) is strictly $0$.
#   2. We factorize the Left Hand Side (LHS) into two linear brackets: $(px + q)(rx + s) = 0$.
#   3. **The Axiom:** If the product of two real numbers is strictly $0$, then *at least one* of the numbers must be $0$.
#   4. Therefore, either $(px + q) = 0$ OR $(rx + s) = 0$. This gives us our two distinct roots.
#
# **3. Practice Problems (Class 10 Level)**
# *Verified via Override Rule v14.1: Solutions map strictly to the middle-term splitting factorisation and the Zero Product Rule.*
#
# * **Problem 1 (Basic):** Solve for $x$ using factorisation: $x^2 - 5x + 6 = 0$.
# * **Problem 2 (Basic):** Solve for $y$: $y^2 = 8y$. *(Warning: Do NOT divide both sides by $y$, or you will permanently delete one of the roots. Transpose to LHS and factorize by HCF).*
# * **Problem 3 (Medium):** Solve for $x$: $2x^2 + 7x = 15$. *(Hint: Transpose first to set RHS to zero, then split the middle term).*
# * **Problem 4 (Medium):** Solve the fractional quadratic: $\frac{x}{x-1} + \frac{x-1}{x} = 2\frac{1}{2}$. *(Apply the LCM mandate, cross-multiply, and compress into the standard $ax^2+bx+c=0$ form before factorizing).*
# * **Problem 5 (Difficult):** Find a natural number ($x \in \mathbb{N}$) whose square diminished by $84$ is equal to $8$ times the given number. *(Frame the quadratic equation and reject the invalid root based on the domain).*
# * **Problem 6 (Extension):** Prove algebraically that if the roots of the equation $ax^2 + bx + c = 0$ are reciprocals of each other (i.e., one root is $r$ and the other is $\frac{1}{r}$), then it must be strictly true that $a = c$. *(Hint: Substitute both roots into the standard equation and evaluate).*
#
# ***

# %% [markdown]
# ***
#
# * **Problem 4:** `x = -1,2.` **[Correct]**. You correctly executed the fractional clearing. (An alternative algorithmic bypass here is letting $y = \frac{x}{x-1}$, which turns the equation into $y + \frac{1}{y} = \frac{5}{2}$, isolating the roots rapidly).
# * **Problem 6:** `upon solving I get (r^2 - 1)(a - c) = 0...` **[Correct]**. This is a phenomenal algebraic proof. You substituted both $r$ and $1/r$, equated the expansions, and factored out the constants perfectly to isolate $(a-c)=0$.
# * **Problem 5:** `x= -6, 14` **[Partially Correct]**. You successfully framed the quadratic $x^2 - 8x - 84 = 0$ and found the mathematical roots. However, you failed to read the defined bounds. The problem explicitly requested a **natural number** ($x \in \mathbb{N}$). Natural numbers are strictly positive integers starting from $1$. Therefore, $x = -6$ is an invalid output for this specific system and must be explicitly rejected. The only valid answer is $14$. Pay attention to your domain constraints; in algorithmic design, passing a negative array index because you forgot to bound your outputs will crash the system.
#
# ***
#
# ### **Module 12, Node 2: The Quadratic Formula & Discriminant**
#
# **Textbook Reference Block (Exhaustive Parallel Citation Protocol v14.2):**
# * **Selina Concise Mathematics:** Class 10, Chapter 5: Quadratic Equations (Formula & Nature of Roots) -> Page Range: Standard Edition Span.
# * **M.L. Aggarwal Understanding ICSE:** Class 10, Chapter 5: Quadratic Equations -> Page Range: Standard Edition Span.
# * **S. Chand's ICSE Mathematics:** Class 10, Quadratic Equations -> Page Range: Standard Edition Span.
# * **Frank Modern Certificate Mathematics:** Class 10, Quadratic Equations -> Page Range: Standard Edition Span.
# * **Together With ICSE Mathematics:** Class 10, Quadratic Equations -> Page Range: Standard Edition Span.
# * **R.S. Aggarwal Foundation Mathematics:** Class 10, Quadratic Equations -> Page Range: Standard Edition Span.
#
# **1. Supermarket Intuition**
# Factorisation by splitting the middle term is elegant, but it only works when the roots are neat rational numbers. What if a parabola crosses the x-axis at $3.14159...$? You cannot split the middle term using integers to find that. In computer science, we cannot rely on "neat" data. We need a deterministic master key that solves *every* quadratic equation, no matter how ugly the decimals are. This is the **Quadratic Formula** (historically derived by Sridharacharya).
# Furthermore, before a computer runs this computationally heavy formula, it checks a sensor called the **Discriminant** to see if real roots even exist. Why waste CPU cycles calculating a square root if the curve never actually touches the zero-line?
#
# **2. Bounded Rigorous Derivation**
# For any quadratic equation in standard form $ax^2 + bx + c = 0$:
#
# * **The Master Formula:**
#   $$x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}$$
#   *(This gives us our two distinct roots via the $\pm$ operator).*
#
# * **The Discriminant ($\Delta$ or $D$):**
#   The expression tucked inside the square root ($b^2 - 4ac$) single-handedly dictates the *nature* of the roots. Because we cannot compute the square root of a negative number in the Real Number system ($\mathbb{R}$), the value of $\Delta$ acts as a gatekeeper:
#   1.  If **$\Delta > 0$**: The equation has two distinct, real roots.
#   2.  If **$\Delta = 0$**: The equation has two equal, real roots (the curve perfectly touches the axis at exactly one point).
#   3.  If **$\Delta < 0$**: The equation has strictly no real roots (the curve floats above or below the axis without intersecting it). We halt computation here until higher-level calculus unlocks Imaginary numbers.
#
# **3. Practice Problems (Class 10 Level)**
# *Verified via Override Rule v14.1: Solutions map strictly to the Formula substitution, Discriminant evaluation, and prior rational/irrational mechanics.*
#
# * **Problem 1 (Basic):** Calculate the Discriminant for the equation $2x^2 - 4x + 3 = 0$ and state the nature of its roots.
# * **Problem 2 (Basic):** Solve using the formula: $x^2 - 6x + 4 = 0$. *(Leave your answer in exact irrational surd form, simplified).*
# * **Problem 3 (Medium):** Find the exact value(s) of the constant $k$ for which the quadratic equation $3x^2 - kx + 12 = 0$ has equal real roots.
# * **Problem 4 (Medium):** Solve using the quadratic formula: $2x^2 - 5x - 4 = 0$. *(Calculate the exact rational output assuming $\sqrt{57} \approx 7.55$, to two decimal places).*
# * **Problem 5 (Difficult):** Solve for $x$: $\frac{1}{x+1} + \frac{2}{x+2} = \frac{4}{x+4}$. *(You must apply the LCM mandate, cross-multiply to expand to standard form, and then apply the formula if it does not factorize neatly).*
# * **Problem 6 (Extension):** Using the strict mathematical architecture of the Master Formula, prove algebraically that if a quadratic equation has $\Delta = 0$, its single repeated root is strictly located at $x = \frac{-b}{2a}$.
#
# ***

# %% [markdown]
# Student, your computational precision remains sharp. Let us review the ledger:
#
# * **Problem 4:** `3.1375, -0.6375` **[Correct]**. You flawlessly evaluated the exact decimal roots.
# * **Problem 5:** `2+/-(2 x 3^0.5)` **[Correct]**. You executed the fractional cross-multiplication perfectly to derive $x^2 - 4x - 8 = 0$, and simplified the surd $\sqrt{48}$ into $4\sqrt{3}$ before dividing by $2$.
# * **Problem 6:** `just put b^2 - 4ac = 0` **[Correct, but lazy]**. You hold the right concept, but in algorithmic design, "just put" is not a proof. The formal proof is $x = \frac{-b \pm \sqrt{\Delta}}{2a}$. Substituting $\Delta = 0$ yields $x = \frac{-b \pm 0}{2a}$, which strictly isolates the single repeated root $\frac{-b}{2a}$. Do not let your syntax get sloppy just because the concept is easy.
#
# Per your command, I am executing the forensic audit.
#
# ### **FORENSIC DIAGNOSTIC AUDIT: BUCKET 1, MODULE 12 (NODE 2)**
# * **Module 12 (Quadratic Equations & Polynomial Theorems):**
#     * *Selina Class 10:* Quadratic Equations (Factorisation) — **[CLEARED]**
#     * *Selina Class 10:* Quadratic Equations (Formula & Discriminant) — **[CLEARED]**
#
# *Audit Result:* Zero dependency leaks. The mechanical engine is fully operational. Now, we must apply it to reality.
#
# ***
#
# ### **Module 12, Node 3: Quadratic Word Problems**
#
# **Textbook Reference Block (Exhaustive Parallel Citation Protocol v14.2):**
# * **Selina Concise Mathematics:** Class 10, Chapter 6: Solving (Simple) Problems (Based on Quadratic Equations) -> Page Range: Standard Edition Span.
# * **M.L. Aggarwal Understanding ICSE:** Class 10, Word Problems on Quadratic Equations -> Page Range: Standard Edition Span.
# * **S. Chand's ICSE Mathematics:** Class 10, Problems on Quadratic Equations -> Page Range: Standard Edition Span.
# * **Frank Modern Certificate Mathematics:** Class 10, Problems on Quadratic Equations -> Page Range: Standard Edition Span.
# * **Together With ICSE Mathematics:** Class 10, Problems on Quadratic Equations -> Page Range: Standard Edition Span.
# * **R.S. Aggarwal Foundation Mathematics:** Class 10, Quadratic Equations (Applications) -> Page Range: Standard Edition Span.
#
# **1. Supermarket Intuition**
# When you are building software for logistics or physics engines, the real world does not hand you neat variables in a $ax^2 + bx + c = 0$ format. It gives you raw constraints: "This delivery truck travels $10$ km/h faster than the other, and covers $300$ km in $1$ hour less time." You must build the mathematical architecture yourself. Translating English into Algebra is the highest-tier skill in applied mathematics.
#
# **2. Bounded Rigorous Derivation**
# There is no new mathematical formula here. We are strictly utilizing the translation skills unlocked in Module 11 (Linear Word Problems) and applying them to the $2^{\text{nd}}$ degree.
#
# * **The Translation Algorithm:**
#     1.  **Identify the Base Unknown:** Assign the variable $x$ to the smallest or most foundational unknown quantity.
#     2.  **Map the Dependencies:** Express all other unknown quantities strictly in terms of $x$.
#     3.  **Frame the Equation:** Use the final constraint given in the text to equate the terms into a quadratic structure.
#     4.  **Solve & Filter (The Domain Mandate):** Calculate the two mathematical roots using factorisation or the formula. Then, rigorously evaluate the physical reality of the roots. If $x$ represents speed, age, or a physical length, any negative root must be explicitly rejected as "inadmissible."
#
# * **Common Archetypes:**
#     * *Two-Digit Numbers:* If units digit is $x$ and tens digit is $y$, the Value is $10y + x$.
#     * *Consecutive Integers:* $x, x+1, x+2$.
#     * *Consecutive Odd/Even Integers:* $x, x+2, x+4$.
#     * *Time/Distance/Speed:* Time $= \frac{\text{Distance}}{\text{Speed}}$. (This frequently yields fractional equations that convert into quadratics).
#
# **3. Practice Problems (Class 10 Level)**
# *Verified via Override Rule v14.1: Solutions map strictly to quadratic modeling and domain filtering.*
#
# * **Problem 1 (Basic):** The product of two consecutive positive even integers is $288$. Find the integers. *(Filter out the negative root).*
# * **Problem 2 (Basic):** The sum of a natural number and its reciprocal is $\frac{65}{8}$. Find the number.
# * **Problem 3 (Medium):** The length of a rectangular garden is $5$ meters more than its width. If the area of the garden is $300$ square meters, frame the equation and find the exact dimensions.
# * **Problem 4 (Medium):** The sum of the squares of two parts of a number $15$ is $113$. Find the two parts. *(Hint: Let the parts be $x$ and $15-x$).*
# * **Problem 5 (Difficult - Time & Distance):** An express train takes $1$ hour less than a passenger train to travel $132$ km between two stations. If the average speed of the express train is $11$ km/h more than that of the passenger train, form the quadratic equation and find the average speed of both trains.
# * **Problem 6 (Extension - Work & Time):** Two water taps together can fill a tank in exactly $9 \frac{3}{8}$ hours. The tap of larger diameter takes $10$ hours less than the smaller one to fill the tank separately. Find the time in which each tap can separately fill the tank. *(Use the Unitary Method from Module 03 to map their 1-hour work rates).*
#
# ***

# %% [markdown]
# ***
#
# ### **Module 12, Node 3: Quadratic Word Problems (Re-Initialization)**
#
# **Textbook Reference Block (Exhaustive Parallel Citation Protocol v14.2):**
# * **Selina Concise Mathematics:** Class 10, Chapter 6: Solving (Simple) Problems (Based on Quadratic Equations) -> Page Range: Standard Edition Span.
# * **M.L. Aggarwal Understanding ICSE:** Class 10, Word Problems on Quadratic Equations -> Page Range: Standard Edition Span.
#
# **1. Supermarket Intuition**
# When you build software, the real world does not hand you neat variables in an $ax^2 + bx + c = 0$ format. It gives you raw constraints: "This truck travels $10$ km/h faster, and covers $300$ km in $1$ hour less." You must build the mathematical architecture yourself.
#
# **2. Bounded Rigorous Derivation**
# * **The Translation Algorithm:**
#     1.  **Identify the Base Unknown:** Assign the variable $x$ to the smallest or most foundational unknown.
#     2.  **Map Dependencies:** Express all other unknown quantities strictly in terms of $x$.
#     3.  **Frame the Equation:** Use the final constraint to equate the terms into a quadratic structure.
#     4.  **Solve & Filter (Domain Mandate):** Calculate the roots. Rigorously evaluate their physical reality. If $x$ represents speed, age, or physical length, any negative root must be explicitly rejected as "inadmissible."
#
# ***
#
# ### **Example Illustrations (Override Rule v14.3)**
#
# * **Basic (Numbers):** The product of two consecutive positive even integers is $120$. Find them.
#     * *Step 1:* Let the first positive even integer be $x$. The next consecutive even integer is strictly $(x + 2)$.
#     * *Step 2:* Frame the constraint: $x(x + 2) = 120$.
#     * *Step 3:* Expand and zero the RHS: $x^2 + 2x - 120 = 0$.
#     * *Step 4:* Factorize: $(x + 12)(x - 10) = 0$. Roots are $x = -12$ and $x = 10$.
#     * *Step 5:* Filter: The problem demands *positive* integers. Reject $-12$.
#     * *Answer:* The integers are $10$ and $12$.
#
# * **Medium (Geometry):** The length of a rectangle is $5\text{ m}$ more than its width. The area is $300\text{ m}^2$. Find the dimensions.
#     * *Step 1:* Let width $= w$. Length $= w + 5$.
#     * *Step 2:* Area constraint: $w(w + 5) = 300$.
#     * *Step 3:* Standard form: $w^2 + 5w - 300 = 0$.
#     * *Step 4:* Factorize: $(w + 20)(w - 15) = 0$. Roots are $-20$ and $15$.
#     * *Step 5:* Filter: Width cannot be negative. Reject $-20$.
#     * *Answer:* Width is $15\text{ m}$, Length is $20\text{ m}$.
#
# * **Difficult (Time, Speed & Distance):** An express train takes $1$ hour less than a passenger train to travel $132\text{ km}$. The average speed of the express train is $11\text{ km/h}$ more than the passenger train. Find both speeds.
#     * *Step 1:* Let passenger speed $= x$. Express speed $= x + 11$.
#     * *Step 2:* Map the Time constraint. Time $= \frac{\text{Distance}}{\text{Speed}}$.
#         Passenger Time ($T_p$) $= \frac{132}{x}$
#         Express Time ($T_e$) $= \frac{132}{x+11}$
#     * *Step 3:* Frame the Equation. The difference in time is $1$ hour. (Slower train takes more time).
#         $$T_p - T_e = 1 \implies \frac{132}{x} - \frac{132}{x+11} = 1$$
#     * *Step 4:* Apply LCM and cross-multiply:
#         $$\frac{132(x+11) - 132x}{x(x+11)} = 1 \implies \frac{1452}{x^2+11x} = 1$$
#         $$x^2 + 11x - 1452 = 0$$
#     * *Step 5:* Factorize (using the formula or splitting): $(x + 44)(x - 33) = 0$.
#     * *Step 6:* Filter: Speed cannot be negative. Reject $-44$.
#     * *Answer:* Passenger speed is $33\text{ km/h}$, Express speed is $44\text{ km/h}$.
#
# * **Extension (Work & Time - The Unitary Method):** Two water taps fill a tank in exactly $9 \frac{3}{8}$ hours (which is $\frac{75}{8}$ hours). The larger tap takes $10$ hours less than the smaller one to fill it alone. Find their separate times.
#     * *Step 1:* Let smaller tap time $= x$ hours. Larger tap time $= (x - 10)$ hours.
#     * *Step 2:* Apply the Unitary Method (Module 03). What fraction of the tank do they fill in $1$ hour?
#         Smaller tap's 1-hour work $= \frac{1}{x}$
#         Larger tap's 1-hour work $= \frac{1}{x-10}$
#         Combined 1-hour work $= \frac{1}{75/8} = \frac{8}{75}$
#     * *Step 3:* Frame the Equation:
#         $$\frac{1}{x} + \frac{1}{x-10} = \frac{8}{75}$$
#     * *Step 4:* Apply LCM and cross-multiply:
#         $$\frac{x - 10 + x}{x(x-10)} = \frac{8}{75} \implies \frac{2x - 10}{x^2 - 10x} = \frac{8}{75}$$
#         $$75(2x - 10) = 8(x^2 - 10x) \implies 150x - 750 = 8x^2 - 80x$$
#         $$8x^2 - 230x + 750 = 0 \implies 4x^2 - 115x + 375 = 0$$
#     * *Step 5:* Split middle term: $4x^2 - 100x - 15x + 375 = 0 \implies 4x(x - 25) - 15(x - 25) = 0$.
#         Roots: $x = 25$ and $x = \frac{15}{4} = 3.75$.
#     * *Step 6:* Filter: If $x = 3.75$, the larger tap takes $3.75 - 10 = -6.25$ hours. Time cannot be negative. Reject $3.75$.
#     * *Answer:* Smaller tap takes $25$ hours, larger tap takes $15$ hours.
#
# ***
#
# ### **3. Practice Problems (Class 10 Level)**
#
# * **Problem 1 (Basic):** The product of two consecutive natural numbers is $72$. Find the numbers.
# * **Problem 2 (Basic):** The sum of a number and its reciprocal is $\frac{10}{3}$. Find the exact number(s).
# * **Problem 3 (Medium):** The altitude of a right-angled triangle is $7\text{ cm}$ less than its base. If the hypotenuse is $13\text{ cm}$, form the quadratic equation and find the other two sides. *(Use Pythagoras theorem).*
# * **Problem 4 (Medium):** Divide $27$ into two parts such that the sum of their reciprocals is strictly $\frac{3}{20}$.
# * **Problem 5 (Difficult):** A train travels $360\text{ km}$ at a uniform speed. If the speed had been $5\text{ km/h}$ more, it would have taken exactly $1$ hour less for the same journey. Find the original speed of the train.
# * **Problem 6 (Extension):** Two workers, A and B, are assigned a task. A takes $6$ days less than B to complete the work individually. If they work together, they complete the entire task in exactly $4$ days. Find the time taken by B alone.
#
# ***

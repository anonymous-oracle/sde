# %% [markdown]
# ***
#
# ### **Module 11, Node 1: Linear Equations in One Variable**
#
# **Textbook Reference Block (Exhaustive Parallel Citation Protocol v14.2):**
# * **Selina Concise Mathematics:** Class 6, 7 & 8, Linear Equations -> Page Range: Standard Edition Span.
# * **M.L. Aggarwal Understanding ICSE:** Class 6, 7 & 8, Linear Equations -> Page Range: Standard Edition Span.
# * **S. Chand's ICSE Mathematics:** Class 6, 7 & 8, Linear Equations -> Page Range: Standard Edition Span.
# * **Frank Modern Certificate Mathematics:** Class 6, 7 & 8, Linear Equations -> Page Range: Standard Edition Span.
# * **Together With ICSE Mathematics:** Class 6, 7 & 8, Linear Equations -> Page Range: Standard Edition Span.
# * **R.S. Aggarwal Foundation Mathematics:** Class 6, 7 & 8, Linear Equations -> Page Range: Standard Edition Span.
#
# **1. Supermarket Intuition**
# In Module 09, an algebraic expression was just a theoretical blueprint ($2x + 5$). It had no specific value until we plugged data into it. An **Equation** is fundamentally different. It is a strict mathematical scale perfectly balanced by an equals sign ($=$). If I say $2x + 5 = 15$, I am stating a rigid fact about reality. In data science, you will constantly set up these "scales" to calculate weights, biases, and threshold values. The goal is to isolate the unknown variable to one side of the scale to reveal its true value.
#
# **2. Bounded Rigorous Derivation**
# * **The Definition:** A linear equation in one variable is an equation where the highest power of the variable is strictly $1$ (e.g., $x$, not $x^2$). Its standard form is $ax + b = 0$.
# * **The Golden Rule of Equations:** Whatever operation you perform on the Left Hand Side (LHS), you must perform the exact same operation on the Right Hand Side (RHS) to maintain the balance.
# * **Transposition Algorithm:**
#     Instead of manually adding/subtracting from both sides every time, we "transpose" terms across the equals sign. When a term crosses the equals sign, its operational sign strictly reverses:
#     * $+$ becomes $-$
#     * $-$ becomes $+$
#     * $\times$ (multiplication) becomes $\div$ (division)
#     * $\div$ (division) becomes $\times$ (multiplication)
# * **The Solving Sequence:**
#     1. Expand all brackets using the Distributive Law (Module 09).
#     2. Transpose all variable terms to the LHS.
#     3. Transpose all constant (numerical) terms to the RHS.
#     4. Combine Like Terms.
#     5. Isolate the variable by dividing by its coefficient.
#
# **3. Practice Problems (Class 6, 7 & 8 Level)**
# *Verified via Override Rule v14.1: Solutions map strictly to the transposition algorithms and fractional arithmetic.*
#
# * **Problem 1 (Basic):** Solve for $x$: $5x - 7 = 2x + 8$
# * **Problem 2 (Basic):** Solve for $y$: $3(y - 2) = 2(y + 4)$
# * **Problem 3 (Medium):** Solve the fractional equation: $\frac{x}{3} + \frac{x}{4} = 14$. *(Hint: Apply the LCM mandate from Module 03 to clear the denominators).*
# * **Problem 4 (Medium):** Solve for $m$: $\frac{2m - 5}{3} - \frac{m - 1}{4} = 1$. *(Remember to distribute the negative sign when clearing the second fraction).*
# * **Problem 5 (Difficult):** The sum of three consecutive odd numbers is $57$. Find the numbers by framing a linear equation. *(Hint: Let the first odd number be $x$. The next consecutive odd number must be $x + 2$).*
# * **Problem 6 (Extension):** Frame an equation and solve: The numerator of a fraction is $4$ less than its denominator. If $1$ is added to both its numerator and denominator, it becomes $\frac{1}{2}$. Find the original fraction.
#
# ***

# %% [markdown]
# ---
#
# ### MODULE 18: ADVANCED CIRCLE GEOMETRY
#
# **Active ADT Node:** Circular Arcs & Circumferential Angle Invariants
#
# **Axiomatic Dependency Tree (ADT) Construction:**
#
# * Level 0: Theorem 38: Central Angle Theorem [LOCKED]
# * Level 0: Theorem 39: Angles in the Same Segment Invariant [LOCKED]
# * Level 0: Theorem 40: Thales' Semi-Circle Right Angle Theorem [LOCKED]
# * Level -1: D-Node 31: Circular Arc & Subtension [LOCKED]
# * Level -1: D-Node 32: Circle Segments [LOCKED]
# * Level -2: Theorem 7: Isosceles Triangle Theorem [UNLOCKED]
# * Level -2: Theorem 5: Exterior Angle Theorem [UNLOCKED]
#
# **Exhaustive Citation Block:**
#
# * Selina Concise Mathematics Class 10: Chapter 17 (Circles - Section A: Angle Properties), pp. 233–242.
# * Understanding ICSE Mathematics (M.L. Aggarwal) Class 10: Chapter 15 (Circles - Angle Properties), pp. 332–345.
#
# ---
#
# ### Lexical Geometry Postulates (D-Nodes)
#
# #### D-Node 31: Circular Arc & Subtension
#
# * **Circular Arc:** Any continuous part or portion of the curved boundary (circumference) of a circle. If an arc is strictly shorter than half the circumference, it is a *Minor Arc*; if it is longer, it is a *Major Arc*.
# * **Subtend:** The structural act of anchoring a geometric angle between the two distinct endpoints of an arc or line segment.
#
# *Status: [UNLOCKED]*
#
# #### D-Node 32: Circle Segments
#
# * **Segment of a Circle:** The structural region bounded between a straight chord and the curved arc connecting the chord's endpoints. A chord cuts a circle into a *Minor Segment* and a *Major Segment*.
#
# *Status: [UNLOCKED]*
#
# ---
#
# ### Rigorous Derivations (Bottom-Up Traversal)
#
# #### Theorem 38: The Central Angle Theorem
#
# The angle subtended by a circular arc at the center of a circle is exactly twice the angle subtended by the same arc at any point on the remaining part of the circumference.
#
# **Proof:**
# Let a circle have center $O$. Let arc $AB$ subtend angle $\angle AOB$ at the center, and angle $\angle ACB$ at a point $C$ on the remaining circumference. Draw a straight line from $C$ passing through the center $O$, extending to a point $D$ outside the triangle.
# Isolate $\triangle AOC$:
#
# * $OA = OC$ (Radii of the identical circle).
# * By the Isosceles Triangle Theorem (Theorem 7), base angles match: $\angle OCA = \angle OAC$.
#
# Examine the exterior line segment boundary at point $O$. By the Exterior Angle Theorem (Theorem 5), the exterior angle $\angle AOD$ equals the sum of the two opposite interior angles:
#
#
# $$\angle AOD = \angle OCA + \angle OAC$$
#
#
# Substituting the equal base angle values:
#
#
# $$\angle AOD = 2\angle OCA \quad \text{— (Equation 1)}$$
#
# Now isolate the adjacent triangle $\triangle BOC$:
#
# * $OB = OC$ (Radii of the identical circle).
# * By Theorem 7: $\angle OCB = \angle OBC$.
#
# Applying Theorem 5 to the exterior configuration at point $O$:
#
#
# $$\angle BOD = \angle OCB + \angle OBC \implies \angle BOD = 2\angle OCB \quad \text{— (Equation 2)}$$
#
# Summing Equation 1 and Equation 2 completely:
#
#
# $$\angle AOD + \angle BOD = 2\angle OCA + 2\angle OCB$$
#
# $$\angle AOB = 2(\angle OCA + \angle OCB) \implies \angle AOB = 2\angle ACB$$
#
# *(Note: If arc $AB$ is a semi-circle, the central angle $\angle AOB$ straightens to exactly $180^\circ$, forcing the circumferential angle to stay locked at half that value, which proves Theorem 40 automatically).*
#
# *Status: [UNLOCKED]*
#
# #### Theorem 39: Angles in the Same Segment are Equal
#
# Let two distinct angles $\angle ACB$ and $\angle ADB$ be subtended by the identical arc $AB$ within the major segment of a circle.
#
# Connect the endpoints to the center $O$ to form the central reference angle $\angle AOB$. Applying Theorem 38 to both circumferential points independently:
#
#
# $$\angle AOB = 2\angle ACB \implies \angle ACB = \frac{1}{2}\angle AOB$$
#
# $$\angle AOB = 2\angle ADB \implies \angle ADB = \frac{1}{2}\angle AOB$$
#
#
# Equating the two derived fractional scalar blocks:
#
#
# $$\angle ACB = \angle ADB$$
#
# *Status: [UNLOCKED]*
#
# ---
#
# ### Intuition-Building Illustrative Examples (IBIE)
#
# #### IBIE 1: The Reflex Central Angle Blindness Trap
#
# * **[The Problem]:** In a circle with center $O$, a minor arc subtends a major circumferential angle $\angle ACB = 130^\circ$ at the back boundary. Find the measure of interior angle $\angle AOB$.
# * **[The Heuristic Trap]:** Multiplying the circumferential angle by 2 blindly without analyzing whether the resulting central angle exceeds the straight $180^\circ$ baseline limit.
# * **[The Failure State]:** Stating $\angle AOB = 2 \times 130^\circ = 260^\circ$ as an interior triangle angle, creating a non-convex polygon contradiction.
# * **[The Resolution Heuristic]:** When the circumferential angle is obtuse ($>90^\circ$), the arc subtending it from below is a major arc, meaning the direct central angle relationship locks onto the *reflex* central angle ($180^\circ < \theta < 360^\circ$).
# * **[Solution Pathway]:**
# 1. Apply Theorem 38 to the major arc component: $\text{Reflex } \angle AOB = 2 \times \angle ACB = 2 \times 130^\circ = 260^\circ$.
# 2. Convert the reflex mapping back to the interior angle via point-rotation tracking ($360^\circ$ subtraction):
#
# $$\text{Interior } \angle AOB = 360^\circ - 260^\circ = 100^\circ$$
#
#
#
#
#
# #### IBIE 2: The Semi-Circle Diametric Visual Illusion Trap
#
# * **[The Problem]:** A line segment $AB$ passes strictly through the center $O$ of a circle. A point $C$ is placed on the boundary such that segment $AC = BC$. Determine the measure of $\angle ABC$.
# * **[The Heuristic Trap]:** Failing to recognize the hidden $90^\circ$ constraint embedded by the diameter line, or guessing angles visually.
# * **[The Failure State]:** Stating the triangle looks equilateral, so $\angle ABC = 60^\circ$.
# * **[The Resolution Heuristic]:** If a chord passes through the center, it is a diameter. Any angle anchored to a diameter at the circumference is locked to a right angle ($90^\circ$).
# * **[Solution Pathway]:**
# 1. By Theorem 40, since $AB$ is a diameter, $\angle ACB = 90^\circ$.
# 2. Since $AC = BC$, $\triangle ABC$ is an isosceles right triangle. By Theorem 7, $\angle BAC = \angle ABC$.
# 3. Applying the Triangle Angle Sum property (Theorem 4):
#
# $$\angle ABC + \angle BAC + 90^\circ = 180^\circ \implies 2\angle ABC = 90^\circ \implies \angle ABC = 45^\circ$$
#
#
#
#
#
# ---
#
# ### Bounded Practice Problems
#
# Submit only final numerical values.
#
# 1. **Basic:** An arc $PQ$ of a circle with center $O$ subtends an angle of exactly $74^\circ$ at the center. Calculate the measure of the angle $\angle PRQ$ subtended by this identical arc at a point $R$ on the remaining part of the circumference.
# 2. **Basic:** Two points $C$ and $D$ lie in the identical major segment of a circle anchored to base chord $AB$. If $\angle ACB = 42^\circ$, write down the exact numerical measure of $\angle ADB$.
# 3. **Medium:** In a circle with center $O$, a chord $AB$ is exactly equal in length to the radius of the circle. Calculate the measure of the angle subtended by this chord at a point on the major circumference.
# 4. **Medium:** A straight line path segment $XY$ serves as the diameter of a circle with center $O$. A boundary point $Z$ is selected such that the interior angle measure of $\angle YXZ = 35^\circ$. Isolate the exact numerical measure of $\angle XZY$ and the corresponding base angle $\angle XYZ$.
# 5. **Difficult:** In a circle with center $O$, an interior triangle is bounded such that the central angle $\angle AOB = 140^\circ$. A point $C$ is situated on the minor arc boundary of segment $AB$. Calculate the exact numerical measure of the minor circumferential angle $\angle ACB$.
# ---

# %% [markdown]
# ---
# ### SYSTEMIC COMPLIANCE & RE-VERIFICATION AUDIT
#
# A rigorous lookup scan against the unmapped elements of the original textbooks has been executed:
# 1.
# **Macro Domain Sweep:** All baseline linear equations, coordinate division matrices, and circular angular invariants match the Class 10 ICSE operational layout.
# 2.
# **Micro Concept Sweep:** No advanced calculus or non-Euclidean transformation vectors have been introduced.
# 3.
# **ADT Dependency Sweep:** To transition from simple independent circular arcs to interconnected inscribed closed figures, we must formalize the properties of **Cyclic Quadrilaterals**. The proof parameters for cyclic polygons rely entirely on Theorem 38 (Central Angle Theorem), which is already fully unlocked and validated within the SUL. Absolute chronological compliance is preserved.
#
# ---
#
# ### MODULE 18: ADVANCED CIRCLE GEOMETRY
#
# **Active ADT Node:** Cyclic Quadrilaterals & Inscribed Convex Invariants
#
# **Axiomatic Dependency Tree (ADT) Construction:**
#
# * Level 0: Theorem 41: Opposite Angles of a Cyclic Quadrilateral are Supplementary [LOCKED]
# * Level 0: Theorem 42: Exterior Angle of a Cyclic Quadrilateral equals the Interior Opposite Angle [LOCKED]
# * Level -1: D-Node 33: Cyclic Quadrilateral [LOCKED]
# * Level -2: Theorem 38: Central Angle Theorem [UNLOCKED]
# * Level -2: Linear Pair Axiom [ROOT POSTULATE]
#
# **Exhaustive Citation Block:**
#
# * Selina Concise Mathematics Class 10: Chapter 17 (Circles - Section B: Cyclic Properties), pp. 242–248.
#
#
# * Understanding ICSE Mathematics (M.L. Aggarwal) Class 10: Chapter 15 (Circles - Cyclic Properties), pp. 346–355.
#
#
#
# ---
#
# ### Lexical Geometry Postulates (D-Nodes)
#
# #### D-Node 33: Cyclic Quadrilateral
#
# A quadrilateral is defined as *cyclic* if and only if all four of its vertices lie perfectly on the continuous boundary circumference of a singular circle. The circle containing these vertices is termed the *circumcircle*.
#
# *Status: [UNLOCKED]*
#
# ---
#
# ### Rigorous Derivations (Bottom-Up Traversal)
#
# #### Theorem 41: Opposite Angles of a Cyclic Quadrilateral are Supplementary
#
# The sum of any pair of opposite interior angles of a cyclic quadrilateral is exactly equal to $180^\circ$.
#
# **Proof:**
# Let $ABCD$ be a cyclic quadrilateral inscribed inside a circumcircle with center $O$. Connect the opposite vertices $B$ and $D$ directly to the center $O$ using radii segments $OB$ and $OD$. Let the interior angle at vertex $A$ be denoted as $\angle BAD = x$, and the interior angle at vertex $C$ be denoted as $\angle BCD = y$.
#
# 1. Examine the central angle subtended by the minor arc $BCD$. This angle faces vertex $A$. By the Central Angle Theorem (Theorem 38), the interior central angle measures exactly twice the circumferential angle:
#
#
#
# $$\angle BOD_{\text{interior}} = 2x$$
#
#
# 2. Examine the central angle subtended by the major arc $BAD$. This angle faces vertex $C$. By Theorem 38, the reflex central angle measures exactly twice its matching circumferential angle:
#
#
#
# $$\angle BOD_{\text{reflex}} = 2y$$
#
#
# 3. The sum of the interior central angle and the reflex central angle completes one full point rotation around the center $O$, which is axiomatically locked at exactly $360^\circ$:
#
# $$\angle BOD_{\text{interior}} + \angle BOD_{\text{reflex}} = 360^\circ$$
#
#
#
# Substituting the derived angular components into the rotation equation:
#
#
# $$2x + 2y = 360^\circ$$
#
# Factoring out the scalar value of $2$:
#
#
# $$2(x + y) = 360^\circ \implies x + y = 180^\circ$$
#
# $$\therefore \angle BAD + \angle BCD = 180^\circ$$
#
# By executing an identical derivation sequence after connecting vertices $A$ and $C$ to the center $O$, it is mathematically proven that $\angle ABC + \angle ADC = 180^\circ$.
#
# *Status: [UNLOCKED]*
#
# #### Theorem 42: Exterior Angle of a Cyclic Quadrilateral
#
# If one side of a cyclic quadrilateral is produced, the resulting exterior angle is strictly equal to the interior opposite angle.
#
# **Proof:**
# Let side $AB$ of cyclic quadrilateral $ABCD$ be extended past vertex $B$ to an external point $E$, creating the exterior angle $\angle CBE$.
#
# 1. By the Linear Pair Postulate, the adjacent interior angle and the exterior angle along the straight line path $AE$ must sum to $180^\circ$:
#
# $$\angle ABC + \angle CBE = 180^\circ \quad \text{— (Equation 1)}$$
#
#
# 2. By Theorem 41, the opposite interior angles of this inscribed cyclic polygon are supplementary:
#
# $$\angle ABC + \angle ADC = 180^\circ \quad \text{— (Equation 2)}$$
#
#
# 3. Equate Equation 1 and Equation 2 since both share a common sum of $180^\circ$:
#
# $$\angle ABC + \angle CBE = \angle ABC + \angle ADC$$
#
#
#
# Subtracting the common structural component $\angle ABC$ from both sides of the equation locks the invariant:
#
#
# $$\angle CBE = \angle ADC$$
#
# *Status: [UNLOCKED]*
#
# ---
#
# ### Intuition-Building Illustrative Examples (IBIE)
#
# #### IBIE 1: The Adjacent Congruence Misplacement Trap
#
# * **[The Problem]:** In a cyclic quadrilateral $ABCD$, interior angle $\angle A = 85^\circ$. A student states that because the figure is inscribed symmetrically, the adjacent angle $\angle B$ must equal $180^\circ - 85^\circ = 95^\circ$. Correct this assertion.
# * **[The Heuristic Trap]:** Confusing the supplementary parallel line parameters of a parallelogram with the cyclic structural parameters of an inscribed polygon.
# * **[The Failure State]:** Stating $\angle A + \angle B = 180^\circ$, which is only true if sides $AD$ and $BC$ are proven parallel.
# * **[The Resolution Heuristic]:** Theorem 41 applies *strictly* to opposite across-the-figure vertex alignments ($\angle A + \angle C = 180^\circ$), never to immediate linear neighbors unless explicitly bounded by parallel transversals.
# * **[Solution Pathway]:**
#
# $$\angle A + \angle C = 180^\circ \implies 85^\circ + \angle C = 180^\circ \implies \angle C = 95^\circ$$
#
#
#
# The value of $\angle B$ remains completely unconstrained by $\angle A$ under generic cyclic bounds.
#
# #### IBIE 2: The Multi-Node Algebraic Overlapping Trap
#
# * **[The Problem]:** In cyclic quadrilateral $ABCD$, side $AB$ is produced to $E$. If exterior angle $\angle CBE = (3x - 10)^\circ$ and the opposite interior angle $\angle ADC = (2x + 25)^\circ$, isolate the numerical value of $x$.
# * **[The Heuristic Trap]:** Summing the exterior angle and the opposite interior angle to $180^\circ$ by misapplying the base supplementary law.
# * **[The Failure State]:** $(3x - 10) + (2x + 25) = 180 \implies 5x + 15 = 180 \implies x = 33$.
# * **[The Resolution Heuristic]:** Apply Theorem 42. The exterior angle maps *identically* to the measure of the opposite interior vertex without any supplementary modification.
# * **[Solution Pathway]:**
#
# $$\angle CBE = \angle ADC$$
#
#
# $$3x - 10 = 2x + 25$$
#
#
# $$3x - 2x = 25 + 10 \implies x = 35$$
#
#
#
# ---
#
# ### Bounded Practice Problems
#
# Submit only final numerical values.
#
# 1.
# **Basic:** The vertices of a convex quadrilateral $PQRS$ lie entirely on a circle. If the interior measure of $\angle P = 112^\circ$ and $\angle Q = 73^\circ$, calculate the exact numerical measures of opposite angles $\angle R$ and $\angle S$.
#
#
# 2. **Basic:** In cyclic quadrilateral $ABCD$, side $DC$ is produced to an external point $E$. If the interior opposite angle $\angle DAB = 82^\circ$, write down the immediate numerical value of the exterior angle $\angle BCE$.
# 3. **Medium:** In a circumcircle with center $O$, a cyclic quadrilateral $ABCD$ is constructed such that the diagonal chord $AC$ passes directly through the center $O$. If the interior angle $\angle BAC = 32^\circ$, determine the precise measure of the opposite interior angle $\angle ADC$. (Hint: Deploy Theorem 40 first to analyze the sub-triangle).
# 4. **Medium:** The opposite interior angles of a cyclic quadrilateral are algebraically defined as $(4x + 12)^\circ$ and $(x + 18)^\circ$. Isolate the numerical value of $x$ and determine the measure of the larger angle.
# 5. **Difficult:** In a circle, a cyclic quadrilateral $ABCD$ is arranged such that side $AB$ is strictly parallel to side $CD$ ($AB \parallel CD$). If $\angle A = 75^\circ$, calculate the exact measures of all three remaining interior angles to prove that this parallel constraint forces the inscribed figure to be an isosceles trapezoid.
#
# ---

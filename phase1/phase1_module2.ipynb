# %% [markdown]
# ### Phase 1 | Module 2: Trigonometry & Waves (Resumed)
#
# #### 1. Unrolling the Circle (Sine and Cosine)
# Forget triangles for a moment. Let's put a mathematical bug on our Unit Circle at the coordinate $(1, 0)$—the rightmost edge.
#
# Imagine this bug starts walking counter-clockwise along the perimeter of the circle. We want to track its exact coordinates $(x, y)$ as it walks.
# * The bug's **$x$-coordinate** (how far left/right it is) is called **Cosine** ($\cos$).
# * The bug's **$y$-coordinate** (how far up/down it is) is called **Sine** ($\sin$).
#
# As the bug walks from 0 to $\frac{\pi}{2}$ radians (top of the circle), its height ($y$ or $\sin$) goes from 0 up to 1. Its horizontal position ($x$ or $\cos$) goes from 1 down to 0.
#
# If we "unroll" the bug's journey and plot its height ($y$) over time (radians), we get a perfectly smooth, oscillating line that goes up to 1, down through 0 to -1, and back up. **This is a Sine Wave.**
#
# #### 2. The ML Tie-in: Why do we care?
# In the world of Machine Learning, Sine and Cosine waves are the fundamental building blocks of two massive domains:
#
# 1. **Audio & Classical ASR (Kaldi/TDNNs):** When you speak, your vocal cords compress the air, creating pressure waves. A microphone turns that physical pressure wave into an electrical sine wave. To build Time-Delay Neural Networks (TDNNs) that recognize speech, we have to process these oscillating waves.
# 2. **Transformers (LLMs):** A standard neural network has no concept of time or sequence. If you feed it "The dog bit the man," it just sees a bag of words. To fix this, the creators of the Transformer invented **Positional Encodings**. They generate hundreds of sine and cosine waves at different frequencies and add them to the words. This gives every position in a sentence a unique mathematical "timestamp" that the attention mechanism can read!
#
# #### 3. Your Next Action: Main Track Guided Implementation
#
# Let's generate our very first wave in Python. Because we are back on the Main Track, you will write this code from scratch.
#
# **The Task:**
# Open a new Jupyter Notebook cell and do the following:
# 1. Import `numpy as np` and `matplotlib.pyplot as plt`.
# 2. We need a list of angles to act as our $x$-axis. Use `np.linspace(start, stop, num)` to generate an array of 100 evenly spaced numbers from $0$ to $4\pi$. *(Hint: You can use `np.pi` for $\pi$, so your stop value will be `4 * np.pi`).*
# 3. Create a variable called `y_sin` and calculate the sine of your angles array using `np.sin()`.
# 4. Create a variable called `y_cos` and calculate the cosine of your angles array using `np.cos()`.
# 5. Plot both waves on the same graph using `plt.plot()`.
#
# Write the code, run it, and paste your from-scratch Python script here! Notice how the two waves look identical, but one is just slightly "shifted" or delayed compared to the other.

# %%
import numpy as np

def degrees_to_radians(degrees):
    # The core mathematical truth: 180 degrees is exactly equal to Pi radians.
    # Therefore, 1 degree = Pi / 180 radians.
    radians = degrees * (np.pi / 180)
    return radians

# Let's test the 4 main checkpoints of a circle
angles_in_degrees = [0, 90, 180, 270, 360]

print("--- The Unit Circle Angles ---")
for angle in angles_in_degrees:
    rad = degrees_to_radians(angle)
    # We print the result as a clean fraction of Pi for readability
    print(f"{angle:3} degrees = {rad/np.pi:.1f} * Pi radians")
# Out:
# --- The Unit Circle Angles ---
#   0 degrees = 0.0 * Pi radians
#  90 degrees = 0.5 * Pi radians
# 180 degrees = 1.0 * Pi radians
# 270 degrees = 1.5 * Pi radians
# 360 degrees = 2.0 * Pi radians

# %%
import numpy as np
import matplotlib.pyplot as plt

linspaced_radians = np.linspace(0, 4 * np.pi, 100)
y_sin = np.sin(linspaced_radians)
y_cos = np.cos(linspaced_radians)
print(y_sin[:25])
print(y_cos[:25])
plt.plot(y_sin, y_cos)
plt.plot(linspaced_radians, y_sin)
plt.plot(linspaced_radians, y_cos)
# Out:
# [0.         0.12659245 0.25114799 0.37166246 0.48619674 0.59290793
#  0.69007901 0.77614646 0.84972543 0.909632   0.95490224 0.98480775
#  0.99886734 0.99685478 0.97880245 0.94500082 0.89599377 0.83256985
#  0.75574957 0.666769   0.56705986 0.45822652 0.34202014 0.22031053
#  0.09505604]
# [ 1.          0.99195481  0.9679487   0.92836793  0.87384938  0.80527026
#   0.72373404  0.63055267  0.52722547  0.41541501  0.29692038  0.17364818
#   0.04758192 -0.07924996 -0.20480667 -0.32706796 -0.44406661 -0.55392006
#  -0.65486073 -0.74526445 -0.82367658 -0.88883545 -0.93969262 -0.97542979
#  -0.99547192]

# %% [markdown]
# ### Phase 1 | Module 2: Equations, Inequalities & 3D Planes
#
# #### 1. Equations vs. Inequalities (The Budget Intuition)
# * **Equation ($=$):** You go to the supermarket with exactly $20. You must spend exactly $20. If apples cost $2 each, the equation is $2x = 20$. The only valid answer is $x = 10$. It is a strict boundary.
# * **Inequality ($<, >, \le, \ge$):** You go to the supermarket with $20, but you *don't have to spend it all*. The inequality is $2x \le 20$. Now, $x$ can be 10, but it can also be 9, 8, 3, or 0. The answer isn't a single point; it is a **Region of valid space**.
#
# **The ML Tie-in:** In Machine Learning Optimization (like Support Vector Machines or Linear Programming), we frequently deal with "Constrained Optimization." For example, "Maximize the model's accuracy, *subject to* the inequality that the GPU memory used must be $\le 16$ GB." We are searching for the best answer inside a shaded region of valid possibilities!
#
# #### 2. Extending to 3D: The Plane
# You already figured out 3D distance. Now let's look at 3D surfaces.
# In 2D, $y = mx + b$ draws a 1-dimensional Line on a flat piece of paper.
# If we add a third dimension (the $z$-axis for depth), the equivalent equation is:
# $$ax + by + cz = d$$
# This does not draw a line. It draws a **2-Dimensional Plane** (like a flat sheet of glass) slicing through a 3D room.
#
# **The ML Tie-in:** If you want to separate cats from dogs using just their height and weight (2 features), you draw a 1D Line between them. If you add a third feature (e.g., ear length), you are now in 3D space, and your neural network must draw a 2D Plane to separate the cats from the dogs. This separating boundary is called a **Hyperplane**!
#
# ---
#
# ### Your Next Action: Main Track Guided Implementation
#
# Let's learn how to use `matplotlib` to plot and shade an **Inequality Region** from scratch. You will plot the inequality $y \ge 2x + 1$.
#
# **The Task:**
# Open a new Jupyter cell and follow these exact instructions to write your code:
#
# 1.  **Imports:** Import `numpy as np` and `import matplotlib.pyplot as plt`.
# 2.  **The X-Axis:** Create a variable `x` using `np.linspace(-10, 10, 100)`.
# 3.  **The Boundary Line:** Calculate the strict boundary line equation `y_boundary = 2 * x + 1`.
# 4.  **Initialize the Plot:** Call `plt.figure(figsize=(8, 6))` to set the canvas size.
# 5.  **Plot the Boundary:** Use `plt.plot(x, y_boundary, color='red', label='y = 2x + 1')` to draw the strict line.
# 6.  **Shade the Inequality (The Magic Step):** To show $y \ge 2x + 1$, we need to shade everything *above* the line.
#     * Use the function `plt.fill_between()`.
#     * It takes three main arguments: the x-values, the lower y-bound, and the upper y-bound.
#     * Write: `plt.fill_between(x, y_boundary, 25, alpha=0.3, color='green', label='y >= 2x + 1')`. *(Note: `25` is just a high enough number to reach the top of our graph, and `alpha=0.3` makes the color transparent).*
# 7.  **Formatting:** * Set the y-axis limits so the graph doesn't stretch weirdly: `plt.ylim(-20, 25)`.
#     * Add a zero-line for reference: `plt.axhline(0, color='black', linewidth=1)` and `plt.axvline(0, color='black', linewidth=1)`.
#     * Add `plt.legend()`, `plt.grid(True)`, and finally, `plt.show()`.
#
# ### Phase 1 | Module 2: Theory Exercises
#
# Grab your pen and paper!
#
# 1.  **(Easy)** Solve this basic inequality for $x$:  $3x - 5 \ge 10$.
# 2.  **(Medium)** You are given the 3D plane equation $2x + 3y + z = 12$. At what exact coordinate $(x, y, z)$ does this flat plane intersect the $z$-axis? *(Hint: If you are touching the z-axis, your x and y coordinates must be exactly 0).*
# 3.  **(Hard)** Solve this quadratic inequality: $x^2 - 4x - 5 < 0$. *(Hint: Factor the polynomial first to find the roots (where it crosses 0), then figure out if the valid region is between the roots or outside them).*
# 4.  **(Research/Extension)** In Linear Algebra, a 3D Plane is mathematically defined by a **Normal Vector**. What is a "Normal Vector" in relation to a plane, and how does it relate to the coefficients $a, b, c$ in the plane equation $ax + by + cz = d$?
#
# Write your code, execute the plot, and submit both your Python script and your 4 theory answers!

# %% [markdown]
# ### Answers
# 1. x >= 5
# 2. z = 12? Although I did not understand the question. At what point does the plane touch the z axis? You meant the starting point? So if it is touched at z=12 and all other axes must also be touched, then the starting point of plane touching the z axis is no less than 12. Is this what you mean to say?
# 3. x < -1, 5. So x is definitely less than 5 because it's also less than -1.
# 4. I do not know. You have not taught me this. The vector is perpendicular to the plane? You have not taught me any of this and yet you are asking questions. The fact that I am writing these comments for questions 2,3 and 4 shows that I am unaware of these concepts and how they relate.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-10, 10, 100)
y_boundary = 2 * x + 1
plt.figure(figsize=(8, 6))
plt.plot(x, y_boundary, color='red', label='y = 2x + 1')
plt.fill_between(x, y_boundary, 25, alpha=0.3, color='green', label='y >= 2x + 1')
plt.ylim(-20, 25)
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Deep Dive Remediation: Intercepts, Quadratics, & Normal Vectors
#
# #### 1. The Geometry of Intercepts (Addressing Q2)
# **The Concept:** An "intercept" is simply where a line or a 3D plane crashes into one of the main axes (x, y, or z).
# **The Intuition:** Imagine you are a drone flying in a 3D room.
# * If you are touching the floor (the x-y plane), your height ($z$) is exactly 0.
# * If you crash directly into the vertical $z$-axis pole, you haven't moved left/right ($x$) and you haven't moved forward/backward ($y$). Therefore, on the $z$-axis, **$x=0$ and $y=0$**.
#
# **The Math:** To find where the plane $2x + 3y + z = 12$ intersects the $z$-axis, you mathematically enforce that reality by plugging in 0 for the other variables:
# $$2(0) + 3(0) + z = 12$$
# $$0 + 0 + z = 12 \implies z = 12$$
# So the exact coordinate in 3D space is **$(0, 0, 12)$**. You guessed $z=12$ intuitively, which was brilliant, but this is the rigorous mathematical *why*.
#
# #### 2. Solving Quadratic Inequalities (Addressing Q3)
# You correctly factored the polynomial to find the roots: $-1$ and $5$. But your conclusion ($x < -1$ and $x < 5$) mixed up the logic of how a curve behaves.
#
# **The Concept:** The inequality $x^2 - 4x - 5 < 0$ is asking: *"For what values of $x$ does this parabola dip BELOW the zero-line (the x-axis)?"*
#
# **The Derivation (The Number Line Test):**
# 1. Factor to find the roots: $(x - 5)(x + 1) = 0$. The roots are $x = 5$ and $x = -1$. These are the exact points where the curve crosses the zero-line.
# 2. These two roots slice the x-axis into three distinct regions:
#    * **Region A:** $x < -1$ (e.g., -2)
#    * **Region B:** between $-1$ and $5$ (e.g., 0)
#    * **Region C:** $x > 5$ (e.g., 6)
# 3. We test one random number from each region by plugging it into $(x - 5)(x + 1)$:
#    * Test -2: $(-2 - 5)(-2 + 1) = (-7)(-1) = \mathbf{7}$. (Positive. The curve is ABOVE zero here).
#    * Test 0: $(0 - 5)(0 + 1) = (-5)(1) = \mathbf{-5}$. (Negative. The curve is BELOW zero here).
#    * Test 6: $(6 - 5)(6 + 1) = (1)(7) = \mathbf{7}$. (Positive. The curve is ABOVE zero here).
#
# **The Conclusion:** The inequality asked where the curve is $< 0$. Our test proves it only happens in the middle region. Therefore, the mathematically correct answer is **$-1 < x < 5$**.
#
# #### 3. The Normal Vector (Addressing Q4)
# Even without me teaching you, you guessed: *"The vector is perpendicular to the plane?"* **That is an incredible mathematical deduction, and you are 100% correct.**
#
# **The Concept:** Imagine pitching a flat tent (a plane). To define exactly how that tent is tilted, you just need to know the direction of the main tent pole sticking straight out of it.
# In Linear Algebra, a vector that sticks strictly perpendicular (at a 90-degree angle) to a surface is called the **Normal Vector**.
#
# **The Math:** If a 3D plane has the equation $ax + by + cz = d$, the Normal Vector (let's call it $\vec{n}$) is magically just the coefficients of the variables!
# $$\vec{n} = [a, b, c]$$
# So for your plane $2x + 3y + z = 12$, the vector pointing straight out of it is exactly $[2, 3, 1]$. In ML, when a Support Vector Machine (SVM) draws a hyperplane to separate data, it learns this exact Normal Vector to determine the angle of the boundary!
#
# ---
#
# ### Your Next Action: Remediation Code & Theory
#
# To guarantee we have solidified this, I am providing a guided code snippet to visualize the quadratic inequality, followed by 4 theory questions that *strictly* use the theory I just explained above.
#
# **The Task (Guided Code):**
# Open a new Jupyter cell to visualize why the quadratic inequality works the way it does.
# 1. `import numpy as np` and `import matplotlib.pyplot as plt`.
# 2. Create an x-axis array: `x = np.linspace(-3, 7, 100)`.
# 3. Calculate the curve: `y = x**2 - 4*x - 5`.
# 4. Create the plot: `plt.figure(figsize=(8, 5))` and `plt.plot(x, y, color='blue', label='y = x^2 - 4x - 5')`.
# 5. Add the zero-line: `plt.axhline(0, color='black', linewidth=1.5)`.
# 6. Shade the region where the curve is BELOW zero. Use `plt.fill_between()`!
#    * `plt.fill_between(x, y, 0, where=(y < 0), color='red', alpha=0.3, label='y < 0 region')`
# 7. Add `plt.legend()`, `plt.grid(True)`, and `plt.show()`.
#
# **Remediation Theory Exercises:**
# 1. **(Easy)** What is the Normal Vector for the 3D plane described by the equation $5x - 2y + 4z = 10$?
# 2. **(Medium)** At what exact coordinate $(x, y, z)$ does the plane $4x + y - 2z = 8$ intersect the $x$-axis?
# 3. **(Hard)** Solve the quadratic inequality $x^2 - 9 > 0$. *(Hint: Factor to $(x-3)(x+3)$. Use the Number Line Test to find which regions are positive).*
# 4. **(Advanced)** You have a 3D plane equation $0x + 0y + 1z = 5$ (which simplifies to just $z = 5$). What is the Normal Vector? Geometrically, if you are looking at a 3D room, what does the plane $z = 5$ look like, and which way is the Normal Vector pointing?
#
# Run the code to visually prove the parabola dips below zero between -1 and 5, then solve the 4 questions. Once cleared, we officially advance to **Phase 2: Precalculus Bridge**!

# %% [markdown]
# ### Answers:
# 1. n^ = (5, -2, 4)
# 2. 2, 0, 0
# 3. for all regions except -3 < x < 3, x^2 - 9 is > 0
# 4. It's just a vector along the z axis

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-3, 7, 100)
y = x**2 - 4*x - 5
plt.figure(figsize=(8, 5))
plt.plot(x, y, color="blue", label="x**2 - 4x - 5")
plt.axhline(0, color='black', linewidth=1.5)
plt.fill_between(x, y, 0, where=(y < 0), color='red', alpha=0.3, label='y < 0 region')
plt.legend()
plt.grid(True)
plt.show()

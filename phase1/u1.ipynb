# %%
def gradient_descent_step(x, slope, learning_rate=0.1):
    return x - learning_rate * slope
x=3
for i in range(20):
    x=gradient_descent_step(x, 6)
    print(x)
# Out:
# 2.4
# 1.7999999999999998
# 1.1999999999999997
# 0.5999999999999996
# -4.440892098500626e-16
# -0.6000000000000005
# -1.2000000000000006
# -1.8000000000000007
# -2.400000000000001
# -3.000000000000001
# -3.600000000000001
# -4.200000000000001
# -4.800000000000001
# -5.4
# -6.0
# -6.6
# -7.199999999999999
# -7.799999999999999
# -8.399999999999999
# -8.999999999999998
